# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('goodreads_books1 .csv')
df2=pd.read_csv('goodreads_books2 .csv')
df3=pd.read_csv('goodreads_books3.csv')

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (3944, 8)
# (4000, 8)
# (802, 8)

# %%
# Concatenate the three DataFrames
combined_df = pd.concat([df1, df2, df3], ignore_index=True)

# Print the shape of the combined DataFrame
print(combined_df.shape)
# Out:
# (8746, 8)

# %%
combined_df
combined_df.to_csv('filename.csv', index=False)

# %%
# Drop duplicate rows
combined_df = combined_df.drop_duplicates()

# Print the shape of the DataFrame after removing duplicates
print(combined_df.shape)
# Out:
# (7756, 8)

# %%
 # Assuming you're using pandas

# Replace 'Not available' with NaN in the entire DataFrame
combined_df=combined_df.replace('Not available', pd.NA)

# %%
combined_df=combined_df.dropna()

# %%
# Save the DataFrame to a CSV file
combined_df.to_csv('all_data.csv', index=False)

# %%
def add_spaces_before_capital(text):
  return ''.join([' ' + char if char.isupper() else char for char in text]).strip()

# Example usage

combined_df['Genre'] = combined_df['Genre'].apply(add_spaces_before_capital)
  # Output: I Am Going To School

# %%
combined_df
# Out:
#                                                   Genre  \
# 0     Genres Fiction Historical  Fiction School Lite...
# 1     Genres Classics Fiction Science  Fiction Dysto...
# 2     Genres Fiction School Historical  Fiction Roma...
# 3     Genres Fantasy Fiction Young  Adult Magic Chil...
# 4     Genres Classics Fiction Dystopia Fantasy Schoo...
# ...                                                 ...
# 8741  Genres Comics Graphic  Novels Bande  Dessinée ...
# 8742  Genres Romance Paranormal Historical Ghosts Pa...
# 8743  Genres History Nonfiction Poland Memoir Polish...
# 8744  Genres Fiction Mystery Historical  Fiction Thr...
# 8745  Genres Comics Graphic  Novels Bande  Dessinée ...
#
#                        Publication Date               Author  \
# 0         First published July 11, 1960           Harper Lee
# 1          First published June 8, 1949        George Orwell
# 2        First published April 10, 1925  F. Scott Fitzgerald
# 3         First published June 26, 1997         J.K. Rowling
# 4       First published August 17, 1945        George Orwell
# ...                                 ...                  ...
# 8741    First published January 1, 1983    François Schuiten
# 8742    First published January 1, 1994        Mickee Madden
# 8743    First published January 1, 1977       Aleksander Wat
# 8744  First published December 27, 1988    Katherine Neville
# 8745    First published January 1, 1984    François Schuiten
#
#                                                   Title Rating  \
# 0                                 To Kill a Mockingbird   4.26
# 1                                                  1984   4.19
# 2                                      The Great Gatsby   3.93
# 3                 Harry Potter and the Sorcerer’s Stone   4.47
# 4                                           Animal Farm   3.99
# ...                                                 ...    ...
# 8741                           Les murailles de Samaris   3.93
# 8742                                        Everlastin'   3.59
# 8743  Secolul meu: confesiunile unui intelectual eur...   4.20
# 8744                                          The Eight   3.93
# 8745                                  Fever in Urbicand   4.15
#
#            Ratings Count    Reviews Count  \
# 0      6,296,391 ratings  120,579 reviews
# 1      4,761,335 ratings  122,911 reviews
# 2      5,365,833 ratings  109,920 reviews
# 3     10,332,287 ratings  167,714 reviews
# 4      4,006,287 ratings  102,011 reviews
# ...                  ...              ...
# 8741         949 ratings       82 reviews
# 8742         214 ratings       30 reviews
# 8743         186 ratings       23 reviews
# 8744      43,688 ratings    3,214 reviews
# 8745         747 ratings       58 reviews
#
#                                         Author Info
# 0                 Harper Lee82 books13.7k followers
# 1           George Orwell1,404 books45.3k followers
# 2     F. Scott Fitzgerald1,933 books24.2k followers
# 3               J.K. Rowling754 books227k followers
# 4           George Orwell1,404 books45.3k followers
# ...                                             ...
# 8741        François Schuiten120 books134 followers
# 8742              Mickee Madden27 books20 followers
# 8743              Aleksander Wat31 books9 followers
# 8744       Katherine Neville24 books1,354 followers
# 8745        François Schuiten120 books134 followers
#
# [7630 rows x 8 columns]

# %%
import re
import pandas as pd
import re

# Assuming you have your DataFrame `combined_df`

combined_df['Genre'] = combined_df['Genre'].apply(lambda x: re.sub(r"[\u0600-\u06FF]", "", x))
combined_df['Genre'] = combined_df['Genre'].apply(lambda x: re.sub(r"[^\w\s]", "", x))
combined_df['Genre'] = combined_df['Genre'].apply(lambda x:  re.sub(r"\.{2,}more", "", x))
combined_df['Genre'] = combined_df['Genre'].apply(lambda x:  re.sub(r"[\d]", "", x))

print(combined_df['Genre'])
# Out:
# 0       Genres Fiction Historical  Fiction School Lite...
# 1       Genres Classics Fiction Science  Fiction Dysto...
# 2       Genres Fiction School Historical  Fiction Roma...
# 3       Genres Fantasy Fiction Young  Adult Magic Chil...
# 4       Genres Classics Fiction Dystopia Fantasy Schoo...
#                               ...
# 8741    Genres Comics Graphic  Novels Bande  Dessinée ...
# 8742    Genres Romance Paranormal Historical Ghosts Pa...
# 8743    Genres History Nonfiction Poland Memoir Polish...
# 8744    Genres Fiction Mystery Historical  Fiction Thr...
# 8745    Genres Comics Graphic  Novels Bande  Dessinée ...
# Name: Genre, Length: 7630, dtype: object

# %%
combined_df['Title'] = combined_df['Title'].apply(lambda x: re.sub(r"[\u0600-\u06FF]", "", x))
combined_df['Title'] = combined_df['Title'].apply(lambda x:  re.sub(r"[\d]", "", x))
combined_df['Title'] = combined_df['Title'].apply(lambda x: re.sub(r"[^\w\s]", "", x))
  # Output: "This is a text with special characters"
print(combined_df['Title'])
# Out:
# 0                                   To Kill a Mockingbird
# 1
# 2                                        The Great Gatsby
# 3                    Harry Potter and the Sorcerers Stone
# 4                                             Animal Farm
#                               ...
# 8741                             Les murailles de Samaris
# 8742                                           Everlastin
# 8743    Secolul meu confesiunile unui intelectual euro...
# 8744                                            The Eight
# 8745                                    Fever in Urbicand
# Name: Title, Length: 7630, dtype: object

# %%
def remove_first_word(text):
  return text[text.find(' ') + 1:]
combined_df['Genre'] = combined_df['Genre'].apply(remove_first_word)

# %%
combined_df
# Out:
#                                                   Genre  \
# 0     Fiction Historical  Fiction School Literature ...
# 1     Classics Fiction Science  Fiction Dystopia Lit...
# 2     Fiction School Historical  Fiction Romance Lit...
# 3     Fantasy Fiction Young  Adult Magic Childrens M...
# 4     Classics Fiction Dystopia Fantasy School Liter...
# ...                                                 ...
# 8741  Comics Graphic  Novels Bande  Dessinée Fantasy...
# 8742  Romance Paranormal Historical Ghosts Paranorma...
# 8743  History Nonfiction Poland Memoir Polish  Liter...
# 8744  Fiction Mystery Historical  Fiction Thriller F...
# 8745  Comics Graphic  Novels Bande  Dessinée Fantasy...
#
#                        Publication Date               Author  \
# 0         First published July 11, 1960           Harper Lee
# 1          First published June 8, 1949        George Orwell
# 2        First published April 10, 1925  F. Scott Fitzgerald
# 3         First published June 26, 1997         J.K. Rowling
# 4       First published August 17, 1945        George Orwell
# ...                                 ...                  ...
# 8741    First published January 1, 1983    François Schuiten
# 8742    First published January 1, 1994        Mickee Madden
# 8743    First published January 1, 1977       Aleksander Wat
# 8744  First published December 27, 1988    Katherine Neville
# 8745    First published January 1, 1984    François Schuiten
#
#                                                   Title Rating  \
# 0                                 To Kill a Mockingbird   4.26
# 1                                                         4.19
# 2                                      The Great Gatsby   3.93
# 3                  Harry Potter and the Sorcerers Stone   4.47
# 4                                           Animal Farm   3.99
# ...                                                 ...    ...
# 8741                           Les murailles de Samaris   3.93
# 8742                                         Everlastin   3.59
# 8743  Secolul meu confesiunile unui intelectual euro...   4.20
# 8744                                          The Eight   3.93
# 8745                                  Fever in Urbicand   4.15
#
#            Ratings Count    Reviews Count  \
# 0      6,296,391 ratings  120,579 reviews
# 1      4,761,335 ratings  122,911 reviews
# 2      5,365,833 ratings  109,920 reviews
# 3     10,332,287 ratings  167,714 reviews
# 4      4,006,287 ratings  102,011 reviews
# ...                  ...              ...
# 8741         949 ratings       82 reviews
# 8742         214 ratings       30 reviews
# 8743         186 ratings       23 reviews
# 8744      43,688 ratings    3,214 reviews
# 8745         747 ratings       58 reviews
#
#                                         Author Info
# 0                 Harper Lee82 books13.7k followers
# 1           George Orwell1,404 books45.3k followers
# 2     F. Scott Fitzgerald1,933 books24.2k followers
# 3               J.K. Rowling754 books227k followers
# 4           George Orwell1,404 books45.3k followers
# ...                                             ...
# 8741        François Schuiten120 books134 followers
# 8742              Mickee Madden27 books20 followers
# 8743              Aleksander Wat31 books9 followers
# 8744       Katherine Neville24 books1,354 followers
# 8745        François Schuiten120 books134 followers
#
# [7630 rows x 8 columns]

# %%
def replace_space_with_comma(text):
  return text.replace(' ', ',')

combined_df['Genre'] = combined_df['Genre'].apply(replace_space_with_comma)

# %%
combined_df
# Out:
#                                                   Genre  \
# 0     Fiction,Historical,,Fiction,School,Literature,...
# 1     Classics,Fiction,Science,,Fiction,Dystopia,Lit...
# 2     Fiction,School,Historical,,Fiction,Romance,Lit...
# 3     Fantasy,Fiction,Young,,Adult,Magic,Childrens,M...
# 4     Classics,Fiction,Dystopia,Fantasy,School,Liter...
# ...                                                 ...
# 8741  Comics,Graphic,,Novels,Bande,,Dessinée,Fantasy...
# 8742  Romance,Paranormal,Historical,Ghosts,Paranorma...
# 8743  History,Nonfiction,Poland,Memoir,Polish,,Liter...
# 8744  Fiction,Mystery,Historical,,Fiction,Thriller,F...
# 8745  Comics,Graphic,,Novels,Bande,,Dessinée,Fantasy...
#
#                        Publication Date               Author  \
# 0         First published July 11, 1960           Harper Lee
# 1          First published June 8, 1949        George Orwell
# 2        First published April 10, 1925  F. Scott Fitzgerald
# 3         First published June 26, 1997         J.K. Rowling
# 4       First published August 17, 1945        George Orwell
# ...                                 ...                  ...
# 8741    First published January 1, 1983    François Schuiten
# 8742    First published January 1, 1994        Mickee Madden
# 8743    First published January 1, 1977       Aleksander Wat
# 8744  First published December 27, 1988    Katherine Neville
# 8745    First published January 1, 1984    François Schuiten
#
#                                                   Title Rating  \
# 0                                 To Kill a Mockingbird   4.26
# 1                                                         4.19
# 2                                      The Great Gatsby   3.93
# 3                  Harry Potter and the Sorcerers Stone   4.47
# 4                                           Animal Farm   3.99
# ...                                                 ...    ...
# 8741                           Les murailles de Samaris   3.93
# 8742                                         Everlastin   3.59
# 8743  Secolul meu confesiunile unui intelectual euro...   4.20
# 8744                                          The Eight   3.93
# 8745                                  Fever in Urbicand   4.15
#
#            Ratings Count    Reviews Count  \
# 0      6,296,391 ratings  120,579 reviews
# 1      4,761,335 ratings  122,911 reviews
# 2      5,365,833 ratings  109,920 reviews
# 3     10,332,287 ratings  167,714 reviews
# 4      4,006,287 ratings  102,011 reviews
# ...                  ...              ...
# 8741         949 ratings       82 reviews
# 8742         214 ratings       30 reviews
# 8743         186 ratings       23 reviews
# 8744      43,688 ratings    3,214 reviews
# 8745         747 ratings       58 reviews
#
#                                         Author Info
# 0                 Harper Lee82 books13.7k followers
# 1           George Orwell1,404 books45.3k followers
# 2     F. Scott Fitzgerald1,933 books24.2k followers
# 3               J.K. Rowling754 books227k followers
# 4           George Orwell1,404 books45.3k followers
# ...                                             ...
# 8741        François Schuiten120 books134 followers
# 8742              Mickee Madden27 books20 followers
# 8743              Aleksander Wat31 books9 followers
# 8744       Katherine Neville24 books1,354 followers
# 8745        François Schuiten120 books134 followers
#
# [7630 rows x 8 columns]

# %%
import re

def replace_commas_after_historical(text):
  return re.sub(r'Historical,+([^A-Z]*[A-Z])', r'Historical \1', text)

combined_df['Genre'] = combined_df['Genre'].apply(replace_commas_after_historical)

# %%
combined_df['Genre']
# Out:
# 0       Fiction,Historical Fiction,School,Literature,Y...
# 1       Classics,Fiction,Science,,Fiction,Dystopia,Lit...
# 2       Fiction,School,Historical Fiction,Romance,Lite...
# 3       Fantasy,Fiction,Young,,Adult,Magic,Childrens,M...
# 4       Classics,Fiction,Dystopia,Fantasy,School,Liter...
#                               ...
# 8741    Comics,Graphic,,Novels,Bande,,Dessinée,Fantasy...
# 8742    Romance,Paranormal,Historical Ghosts,Paranorma...
# 8743    History,Nonfiction,Poland,Memoir,Polish,,Liter...
# 8744    Fiction,Mystery,Historical Fiction,Thriller,Fa...
# 8745    Comics,Graphic,,Novels,Bande,,Dessinée,Fantasy...
# Name: Genre, Length: 7630, dtype: object

# %%
def replace_commas_after_historical(text):
  return re.sub(r'School,+([^A-Z]*[A-Z])', r'School \1', text)

combined_df['Genre'] = combined_df['Genre'].apply(replace_commas_after_historical)

# %%
def replace_double_comma(text):
  return text.replace(',,', ',')

combined_df['Genre'] = combined_df['Genre'].apply(replace_double_comma)

# %%
combined_df['Genre']
# Out:
# 0       Fiction,Historical Fiction,School Literature,Y...
# 1       Classics,Fiction,Science,Fiction,Dystopia,Lite...
# 2       Fiction,School Historical Fiction,Romance,Lite...
# 3       Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...
# 4       Classics,Fiction,Dystopia,Fantasy,School Liter...
#                               ...
# 8741    Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...
# 8742    Romance,Paranormal,Historical Ghosts,Paranorma...
# 8743    History,Nonfiction,Poland,Memoir,Polish,Litera...
# 8744    Fiction,Mystery,Historical Fiction,Thriller,Fa...
# 8745    Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...
# Name: Genre, Length: 7630, dtype: object

# %%
def remove_word_ratings(text):
  return text.replace('ratings', '').replace('rating', '').strip()  # Remove commas and strip whitespace

combined_df['Ratings Count'] = combined_df['Ratings Count'].apply(remove_word_ratings)

# %%
combined_df['Ratings Count'] = combined_df['Ratings Count'].str.replace(',', '') # Remove commas
combined_df['Ratings Count'] = combined_df['Ratings Count'].str.replace(' ', '') # Remove spaces
combined_df['Ratings Count'] = combined_df['Ratings Count'].astype(int) # Convert to int

# %%
def remove_word_reviews(text):
  return text.replace('reviews', '').replace('review', '').strip()  # Remove commas and strip whitespace

combined_df['Reviews Count'] = combined_df['Reviews Count'].apply(remove_word_reviews)

# %%
combined_df['Reviews Count'] = combined_df['Reviews Count'].astype(str)
combined_df['Reviews Count'] = combined_df['Reviews Count'].str.replace(',', '') # Remove commas
combined_df['Reviews Count'] = combined_df['Reviews Count'].astype(int) # Convert to int

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7630 entries, 0 to 8745
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Genre             7630 non-null   object
#  1   Publication Date  7630 non-null   object
#  2   Author            7630 non-null   object
#  3   Title             7630 non-null   object
#  4   Rating            7630 non-null   object
#  5   Ratings Count     7630 non-null   int64
#  6   Reviews Count     7630 non-null   int64
#  7   Author Info       7630 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 536.5+ KB

# %%
def remove_word_Date(text):
  return text.replace('First published', '').strip()

combined_df['Publication Date'] = combined_df['Publication Date'].apply(remove_word_Date)

# %%
import pandas as pd
import numpy as np

def safe_to_datetime(date_str):
    try:
        return pd.to_datetime(date_str, format="%B %d, %Y")
    except (pd.errors.OutOfBoundsDatetime, ValueError):
        return np.nan

# Apply safe conversion to handle out-of-bounds dates
combined_df['Publication Date'] = combined_df['Publication Date'].apply(safe_to_datetime).dt.date

# Display the DataFrame to verify
print(combined_df[['Publication Date']])
# Out:
#      Publication Date
# 0          1960-07-11
# 1          1949-06-08
# 2          1925-04-10
# 3          1997-06-26
# 4          1945-08-17
# ...               ...
# 8741       1983-01-01
# 8742       1994-01-01
# 8743       1977-01-01
# 8744       1988-12-27
# 8745       1984-01-01
#
# [7630 rows x 1 columns]

# %%
combined_df['Publication Date']=pd.to_datetime(combined_df['Publication Date'])

# %%
print(combined_df['Publication Date'].isnull().sum())
# Out:
# 63

# %%
combined_df.isnull().sum().sum()
# Out:
# 63

# %%
combined_df=combined_df.dropna()

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7567 entries, 0 to 8745
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Genre             7567 non-null   object
#  1   Publication Date  7567 non-null   datetime64[ns]
#  2   Author            7567 non-null   object
#  3   Title             7567 non-null   object
#  4   Rating            7567 non-null   object
#  5   Ratings Count     7567 non-null   int64
#  6   Reviews Count     7567 non-null   int64
#  7   Author Info       7567 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 532.1+ KB

# %%
import re

def remove_words_before_number2(text):
  return re.sub(r'^[^\d]*', '', text)

# Example usage on the 'Ratings Count' column:
combined_df['Author Info'] = combined_df['Author Info'].apply(remove_words_before_number2)
# Out:
# <ipython-input-40-26a64a2c25d3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Author Info'] = combined_df['Author Info'].apply(remove_words_before_number2)

# %%
def add_spaces_between_words(text):
  """Adds spaces between words in a given text.

  Args:
    text: The input text.

  Returns:
    The text with spaces added between words.
  """
  words = text.split()
  if not text:  # Check for empty string
    return text

  words = text.split()
  result = ' '.join(words)
  return result

# Example usage on the 'Ratings Count' column:
combined_df['Author Info'] = combined_df['Author Info'].apply(add_spaces_between_words)
combined_df['Author Info']
# Out:
# <ipython-input-41-aede872d2965>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Author Info'] = combined_df['Author Info'].apply(add_spaces_between_words)
# 0          82 books13.7k followers
# 1       1,404 books45.3k followers
# 2       1,933 books24.2k followers
# 3          754 books227k followers
# 4       1,404 books45.3k followers
#                    ...
# 8741        120 books134 followers
# 8742          27 books20 followers
# 8743           31 books9 followers
# 8744       24 books1,354 followers
# 8745        120 books134 followers
# Name: Author Info, Length: 7567, dtype: object

# %%
def add_space_after_books(text):

  text=text.replace('books', '/')
  text= text.replace('book', ' /')
  return text

# Example usage on the 'Reviews Count' column:
combined_df['Author Info'] = combined_df['Author Info'].apply(add_space_after_books)
# Out:
# <ipython-input-42-70d34b289dc2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Author Info'] = combined_df['Author Info'].apply(add_space_after_books)

# %%
combined_df['Author Info']
# Out:
# 0          82 /13.7k followers
# 1       1,404 /45.3k followers
# 2       1,933 /24.2k followers
# 3          754 /227k followers
# 4       1,404 /45.3k followers
#                  ...
# 8741        120 /134 followers
# 8742          27 /20 followers
# 8743           31 /9 followers
# 8744       24 /1,354 followers
# 8745        120 /134 followers
# Name: Author Info, Length: 7567, dtype: object

# %%
# Split the column into two new columns
combined_df[['Auth_Books', 'Auth_Followers']] = combined_df['Author Info'].str.split('/', expand=True)
combined_df
# Out:
# <ipython-input-44-96f312874700>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df[['Auth_Books', 'Auth_Followers']] = combined_df['Author Info'].str.split('/', expand=True)
# <ipython-input-44-96f312874700>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df[['Auth_Books', 'Auth_Followers']] = combined_df['Author Info'].str.split('/', expand=True)
#                                                   Genre Publication Date  \
# 0     Fiction,Historical Fiction,School Literature,Y...       1960-07-11
# 1     Classics,Fiction,Science,Fiction,Dystopia,Lite...       1949-06-08
# 2     Fiction,School Historical Fiction,Romance,Lite...       1925-04-10
# 3     Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...       1997-06-26
# 4     Classics,Fiction,Dystopia,Fantasy,School Liter...       1945-08-17
# ...                                                 ...              ...
# 8741  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...       1983-01-01
# 8742  Romance,Paranormal,Historical Ghosts,Paranorma...       1994-01-01
# 8743  History,Nonfiction,Poland,Memoir,Polish,Litera...       1977-01-01
# 8744  Fiction,Mystery,Historical Fiction,Thriller,Fa...       1988-12-27
# 8745  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...       1984-01-01
#
#                    Author                                              Title  \
# 0              Harper Lee                              To Kill a Mockingbird
# 1           George Orwell
# 2     F. Scott Fitzgerald                                   The Great Gatsby
# 3            J.K. Rowling               Harry Potter and the Sorcerers Stone
# 4           George Orwell                                        Animal Farm
# ...                   ...                                                ...
# 8741    François Schuiten                           Les murailles de Samaris
# 8742        Mickee Madden                                         Everlastin
# 8743       Aleksander Wat  Secolul meu confesiunile unui intelectual euro...
# 8744    Katherine Neville                                          The Eight
# 8745    François Schuiten                                  Fever in Urbicand
#
#      Rating  Ratings Count  Reviews Count             Author Info Auth_Books  \
# 0      4.26        6296391         120579     82 /13.7k followers        82
# 1      4.19        4761335         122911  1,404 /45.3k followers     1,404
# 2      3.93        5365833         109920  1,933 /24.2k followers     1,933
# 3      4.47       10332287         167714     754 /227k followers       754
# 4      3.99        4006287         102011  1,404 /45.3k followers     1,404
# ...     ...            ...            ...                     ...        ...
# 8741   3.93            949             82      120 /134 followers       120
# 8742   3.59            214             30        27 /20 followers        27
# 8743   4.20            186             23         31 /9 followers        31
# 8744   3.93          43688           3214     24 /1,354 followers        24
# 8745   4.15            747             58      120 /134 followers       120
#
#        Auth_Followers
# 0     13.7k followers
# 1     45.3k followers
# 2     24.2k followers
# 3      227k followers
# 4     45.3k followers
# ...               ...
# 8741    134 followers
# 8742     20 followers
# 8743      9 followers
# 8744  1,354 followers
# 8745    134 followers
#
# [7567 rows x 10 columns]

# %%
combined_df['Auth_Followers'] = combined_df['Auth_Followers'].str.replace('followers', '')
combined_df['Auth_Followers'] = combined_df['Auth_Followers'].str.replace('follower', '')
# Out:
# <ipython-input-45-540ac5e9ca81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Followers'] = combined_df['Auth_Followers'].str.replace('followers', '')
# <ipython-input-45-540ac5e9ca81>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Followers'] = combined_df['Auth_Followers'].str.replace('follower', '')

# %%
combined_df['Auth_Followers'].astype(str)
# Out:
# 0       13.7k
# 1       45.3k
# 2       24.2k
# 3        227k
# 4       45.3k
#          ...
# 8741      134
# 8742       20
# 8743        9
# 8744    1,354
# 8745      134
# Name: Auth_Followers, Length: 7567, dtype: object

# %%
combined_df['Auth_Books']
# Out:
# 0          82
# 1       1,404
# 2       1,933
# 3         754
# 4       1,404
#          ...
# 8741      120
# 8742       27
# 8743       31
# 8744       24
# 8745      120
# Name: Auth_Books, Length: 7567, dtype: object

# %%
import pandas as pd
import re


# Extract the number without "k"
#combined_df['Auth_Followers'] = combined_df['Auth_Followers'].astype(str).apply(lambda x: re.sub(r"[^\d\.,]", "", x))
#combined_df['Auth_Books'] = combined_df['Auth_Books'].astype(str).apply(lambda x: re.sub(r"[^\d\.,]", "", x))
combined_df['k1'] = combined_df['Auth_Books'].str.contains('k')
combined_df['k2'] = combined_df['Auth_Followers'].str.contains('k')
# Convert the number to numeric (if needed)
#combined_df['Auth_Followers'] = pd.to_numeric(combined_df['Auth_Followers'], errors='coerce')

# Convert the number to numeric (if needed)
#combined_df['Auth_Books'] = pd.to_numeric(combined_df['Auth_Books'], errors='coerce')


combined_df
# Out:
# <ipython-input-48-77fcfdcfd972>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k1'] = combined_df['Auth_Books'].str.contains('k')
# <ipython-input-48-77fcfdcfd972>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k2'] = combined_df['Auth_Followers'].str.contains('k')
#                                                   Genre Publication Date  \
# 0     Fiction,Historical Fiction,School Literature,Y...       1960-07-11
# 1     Classics,Fiction,Science,Fiction,Dystopia,Lite...       1949-06-08
# 2     Fiction,School Historical Fiction,Romance,Lite...       1925-04-10
# 3     Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...       1997-06-26
# 4     Classics,Fiction,Dystopia,Fantasy,School Liter...       1945-08-17
# ...                                                 ...              ...
# 8741  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...       1983-01-01
# 8742  Romance,Paranormal,Historical Ghosts,Paranorma...       1994-01-01
# 8743  History,Nonfiction,Poland,Memoir,Polish,Litera...       1977-01-01
# 8744  Fiction,Mystery,Historical Fiction,Thriller,Fa...       1988-12-27
# 8745  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...       1984-01-01
#
#                    Author                                              Title  \
# 0              Harper Lee                              To Kill a Mockingbird
# 1           George Orwell
# 2     F. Scott Fitzgerald                                   The Great Gatsby
# 3            J.K. Rowling               Harry Potter and the Sorcerers Stone
# 4           George Orwell                                        Animal Farm
# ...                   ...                                                ...
# 8741    François Schuiten                           Les murailles de Samaris
# 8742        Mickee Madden                                         Everlastin
# 8743       Aleksander Wat  Secolul meu confesiunile unui intelectual euro...
# 8744    Katherine Neville                                          The Eight
# 8745    François Schuiten                                  Fever in Urbicand
#
#      Rating  Ratings Count  Reviews Count             Author Info Auth_Books  \
# 0      4.26        6296391         120579     82 /13.7k followers        82
# 1      4.19        4761335         122911  1,404 /45.3k followers     1,404
# 2      3.93        5365833         109920  1,933 /24.2k followers     1,933
# 3      4.47       10332287         167714     754 /227k followers       754
# 4      3.99        4006287         102011  1,404 /45.3k followers     1,404
# ...     ...            ...            ...                     ...        ...
# 8741   3.93            949             82      120 /134 followers       120
# 8742   3.59            214             30        27 /20 followers        27
# 8743   4.20            186             23         31 /9 followers        31
# 8744   3.93          43688           3214     24 /1,354 followers        24
# 8745   4.15            747             58      120 /134 followers       120
#
#      Auth_Followers     k1     k2
# 0            13.7k   False   True
# 1            45.3k   False   True
# 2            24.2k   False   True
# 3             227k   False   True
# 4            45.3k   False   True
# ...             ...    ...    ...
# 8741           134   False  False
# 8742            20   False  False
# 8743             9   False  False
# 8744         1,354   False  False
# 8745           134   False  False
#
# [7567 rows x 12 columns]

# %%
import pandas as pd
import re

# ... (rest of your code)

combined_df['Auth_Followers'] = combined_df['Auth_Followers'].astype(str).apply(lambda x: re.sub(r"[^\d\.,]", "", x))
combined_df['Auth_Books'] = combined_df['Auth_Books'].astype(str).apply(lambda x: re.sub(r"[^\d\.,]", "", x))
# Out:
# <ipython-input-49-da9d62325edb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Followers'] = combined_df['Auth_Followers'].astype(str).apply(lambda x: re.sub(r"[^\d\.,]", "", x))
# <ipython-input-49-da9d62325edb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Books'] = combined_df['Auth_Books'].astype(str).apply(lambda x: re.sub(r"[^\d\.,]", "", x))

# %%
combined_df
# Out:
#                                                   Genre Publication Date  \
# 0     Fiction,Historical Fiction,School Literature,Y...       1960-07-11
# 1     Classics,Fiction,Science,Fiction,Dystopia,Lite...       1949-06-08
# 2     Fiction,School Historical Fiction,Romance,Lite...       1925-04-10
# 3     Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...       1997-06-26
# 4     Classics,Fiction,Dystopia,Fantasy,School Liter...       1945-08-17
# ...                                                 ...              ...
# 8741  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...       1983-01-01
# 8742  Romance,Paranormal,Historical Ghosts,Paranorma...       1994-01-01
# 8743  History,Nonfiction,Poland,Memoir,Polish,Litera...       1977-01-01
# 8744  Fiction,Mystery,Historical Fiction,Thriller,Fa...       1988-12-27
# 8745  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...       1984-01-01
#
#                    Author                                              Title  \
# 0              Harper Lee                              To Kill a Mockingbird
# 1           George Orwell
# 2     F. Scott Fitzgerald                                   The Great Gatsby
# 3            J.K. Rowling               Harry Potter and the Sorcerers Stone
# 4           George Orwell                                        Animal Farm
# ...                   ...                                                ...
# 8741    François Schuiten                           Les murailles de Samaris
# 8742        Mickee Madden                                         Everlastin
# 8743       Aleksander Wat  Secolul meu confesiunile unui intelectual euro...
# 8744    Katherine Neville                                          The Eight
# 8745    François Schuiten                                  Fever in Urbicand
#
#      Rating  Ratings Count  Reviews Count             Author Info Auth_Books  \
# 0      4.26        6296391         120579     82 /13.7k followers         82
# 1      4.19        4761335         122911  1,404 /45.3k followers      1,404
# 2      3.93        5365833         109920  1,933 /24.2k followers      1,933
# 3      4.47       10332287         167714     754 /227k followers        754
# 4      3.99        4006287         102011  1,404 /45.3k followers      1,404
# ...     ...            ...            ...                     ...        ...
# 8741   3.93            949             82      120 /134 followers        120
# 8742   3.59            214             30        27 /20 followers         27
# 8743   4.20            186             23         31 /9 followers         31
# 8744   3.93          43688           3214     24 /1,354 followers         24
# 8745   4.15            747             58      120 /134 followers        120
#
#      Auth_Followers     k1     k2
# 0              13.7  False   True
# 1              45.3  False   True
# 2              24.2  False   True
# 3               227  False   True
# 4              45.3  False   True
# ...             ...    ...    ...
# 8741            134  False  False
# 8742             20  False  False
# 8743              9  False  False
# 8744          1,354  False  False
# 8745            134  False  False
#
# [7567 rows x 12 columns]

# %%
combined_df.isnull().sum().sum()
# Out:
# 1

# %%
combined_df=combined_df.dropna()

# %%
combined_df
# Out:
#                                                   Genre Publication Date  \
# 0     Fiction,Historical Fiction,School Literature,Y...       1960-07-11
# 1     Classics,Fiction,Science,Fiction,Dystopia,Lite...       1949-06-08
# 2     Fiction,School Historical Fiction,Romance,Lite...       1925-04-10
# 3     Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...       1997-06-26
# 4     Classics,Fiction,Dystopia,Fantasy,School Liter...       1945-08-17
# ...                                                 ...              ...
# 8741  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...       1983-01-01
# 8742  Romance,Paranormal,Historical Ghosts,Paranorma...       1994-01-01
# 8743  History,Nonfiction,Poland,Memoir,Polish,Litera...       1977-01-01
# 8744  Fiction,Mystery,Historical Fiction,Thriller,Fa...       1988-12-27
# 8745  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...       1984-01-01
#
#                    Author                                              Title  \
# 0              Harper Lee                              To Kill a Mockingbird
# 1           George Orwell
# 2     F. Scott Fitzgerald                                   The Great Gatsby
# 3            J.K. Rowling               Harry Potter and the Sorcerers Stone
# 4           George Orwell                                        Animal Farm
# ...                   ...                                                ...
# 8741    François Schuiten                           Les murailles de Samaris
# 8742        Mickee Madden                                         Everlastin
# 8743       Aleksander Wat  Secolul meu confesiunile unui intelectual euro...
# 8744    Katherine Neville                                          The Eight
# 8745    François Schuiten                                  Fever in Urbicand
#
#      Rating  Ratings Count  Reviews Count             Author Info Auth_Books  \
# 0      4.26        6296391         120579     82 /13.7k followers         82
# 1      4.19        4761335         122911  1,404 /45.3k followers      1,404
# 2      3.93        5365833         109920  1,933 /24.2k followers      1,933
# 3      4.47       10332287         167714     754 /227k followers        754
# 4      3.99        4006287         102011  1,404 /45.3k followers      1,404
# ...     ...            ...            ...                     ...        ...
# 8741   3.93            949             82      120 /134 followers        120
# 8742   3.59            214             30        27 /20 followers         27
# 8743   4.20            186             23         31 /9 followers         31
# 8744   3.93          43688           3214     24 /1,354 followers         24
# 8745   4.15            747             58      120 /134 followers        120
#
#      Auth_Followers     k1     k2
# 0              13.7  False   True
# 1              45.3  False   True
# 2              24.2  False   True
# 3               227  False   True
# 4              45.3  False   True
# ...             ...    ...    ...
# 8741            134  False  False
# 8742             20  False  False
# 8743              9  False  False
# 8744          1,354  False  False
# 8745            134  False  False
#
# [7566 rows x 12 columns]

# %%
# Assuming 'combined_df' is your DataFrame
combined_df['k1']= combined_df['k1'].replace({True: 1,False: 0})
combined_df['k2']= combined_df['k2'].replace({True: 1, False: 0})
combined_df['k1']= combined_df['k1'].astype(int)
combined_df['k2']= combined_df['k2'].astype(int)
combined_df['k1'] = combined_df['k1'].replace(1, 1000)
combined_df['k2'] = combined_df['k2'].replace(1, 1000)
combined_df['k1'] = combined_df['k1'].replace(0, 1)
combined_df['k2'] = combined_df['k2'].replace(0, 1)


combined_df
# Out:
# <ipython-input-54-c70a30eb1b9f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k1']= combined_df['k1'].replace({True: 1,False: 0})
# <ipython-input-54-c70a30eb1b9f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k2']= combined_df['k2'].replace({True: 1, False: 0})
# <ipython-input-54-c70a30eb1b9f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k1']= combined_df['k1'].astype(int)
# <ipython-input-54-c70a30eb1b9f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k2']= combined_df['k2'].astype(int)
# <ipython-input-54-c70a30eb1b9f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k1'] = combined_df['k1'].replace(1, 1000)
# <ipython-input-54-c70a30eb1b9f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k2'] = combined_df['k2'].replace(1, 1000)
# <ipython-input-54-c70a30eb1b9f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k1'] = combined_df['k1'].replace(0, 1)
# <ipython-input-54-c70a30eb1b9f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['k2'] = combined_df['k2'].replace(0, 1)
#                                                   Genre Publication Date  \
# 0     Fiction,Historical Fiction,School Literature,Y...       1960-07-11
# 1     Classics,Fiction,Science,Fiction,Dystopia,Lite...       1949-06-08
# 2     Fiction,School Historical Fiction,Romance,Lite...       1925-04-10
# 3     Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...       1997-06-26
# 4     Classics,Fiction,Dystopia,Fantasy,School Liter...       1945-08-17
# ...                                                 ...              ...
# 8741  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...       1983-01-01
# 8742  Romance,Paranormal,Historical Ghosts,Paranorma...       1994-01-01
# 8743  History,Nonfiction,Poland,Memoir,Polish,Litera...       1977-01-01
# 8744  Fiction,Mystery,Historical Fiction,Thriller,Fa...       1988-12-27
# 8745  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...       1984-01-01
#
#                    Author                                              Title  \
# 0              Harper Lee                              To Kill a Mockingbird
# 1           George Orwell
# 2     F. Scott Fitzgerald                                   The Great Gatsby
# 3            J.K. Rowling               Harry Potter and the Sorcerers Stone
# 4           George Orwell                                        Animal Farm
# ...                   ...                                                ...
# 8741    François Schuiten                           Les murailles de Samaris
# 8742        Mickee Madden                                         Everlastin
# 8743       Aleksander Wat  Secolul meu confesiunile unui intelectual euro...
# 8744    Katherine Neville                                          The Eight
# 8745    François Schuiten                                  Fever in Urbicand
#
#      Rating  Ratings Count  Reviews Count             Author Info Auth_Books  \
# 0      4.26        6296391         120579     82 /13.7k followers         82
# 1      4.19        4761335         122911  1,404 /45.3k followers      1,404
# 2      3.93        5365833         109920  1,933 /24.2k followers      1,933
# 3      4.47       10332287         167714     754 /227k followers        754
# 4      3.99        4006287         102011  1,404 /45.3k followers      1,404
# ...     ...            ...            ...                     ...        ...
# 8741   3.93            949             82      120 /134 followers        120
# 8742   3.59            214             30        27 /20 followers         27
# 8743   4.20            186             23         31 /9 followers         31
# 8744   3.93          43688           3214     24 /1,354 followers         24
# 8745   4.15            747             58      120 /134 followers        120
#
#      Auth_Followers  k1    k2
# 0              13.7   1  1000
# 1              45.3   1  1000
# 2              24.2   1  1000
# 3               227   1  1000
# 4              45.3   1  1000
# ...             ...  ..   ...
# 8741            134   1     1
# 8742             20   1     1
# 8743              9   1     1
# 8744          1,354   1     1
# 8745            134   1     1
#
# [7566 rows x 12 columns]

# %%
import numpy as np

# Replace empty strings with NaN
combined_df['Auth_Followers'].replace('', np.nan, inplace=True)
combined_df['Auth_Books'].replace('', np.nan, inplace=True)

# Remove any remaining non-numeric values or fill NaNs if needed
combined_df['Auth_Followers'] = combined_df['Auth_Followers'].str.replace(',', '').astype(float)
combined_df['Auth_Books'] = combined_df['Auth_Books'].str.replace(',', '').astype(float)
# Out:
# <ipython-input-55-5f134f642d25>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Followers'].replace('', np.nan, inplace=True)
# <ipython-input-55-5f134f642d25>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Books'].replace('', np.nan, inplace=True)
# <ipython-input-55-5f134f642d25>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Followers'] = combined_df['Auth_Followers'].str.replace(',', '').astype(float)
# <ipython-input-55-5f134f642d25>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Books'] = combined_df['Auth_Books'].str.replace(',', '').astype(float)

# %%
combined_df.isnull().sum().sum()
combined_df=combined_df.dropna()
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7518 entries, 0 to 8745
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Genre             7518 non-null   object
#  1   Publication Date  7518 non-null   datetime64[ns]
#  2   Author            7518 non-null   object
#  3   Title             7518 non-null   object
#  4   Rating            7518 non-null   object
#  5   Ratings Count     7518 non-null   int64
#  6   Reviews Count     7518 non-null   int64
#  7   Author Info       7518 non-null   object
#  8   Auth_Books        7518 non-null   float64
#  9   Auth_Followers    7518 non-null   float64
#  10  k1                7518 non-null   int64
#  11  k2                7518 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(5)
# memory usage: 763.5+ KB

# %%
combined_df['Auth_Followers']=combined_df['Auth_Followers']*combined_df['k2']

combined_df['Auth_Books']=combined_df['Auth_Books']*combined_df['k1']
# Out:
# <ipython-input-57-43086377365b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Followers']=combined_df['Auth_Followers']*combined_df['k2']
# <ipython-input-57-43086377365b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Auth_Books']=combined_df['Auth_Books']*combined_df['k1']

# %%
combined_df
# Out:
#                                                   Genre Publication Date  \
# 0     Fiction,Historical Fiction,School Literature,Y...       1960-07-11
# 1     Classics,Fiction,Science,Fiction,Dystopia,Lite...       1949-06-08
# 2     Fiction,School Historical Fiction,Romance,Lite...       1925-04-10
# 3     Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...       1997-06-26
# 4     Classics,Fiction,Dystopia,Fantasy,School Liter...       1945-08-17
# ...                                                 ...              ...
# 8741  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...       1983-01-01
# 8742  Romance,Paranormal,Historical Ghosts,Paranorma...       1994-01-01
# 8743  History,Nonfiction,Poland,Memoir,Polish,Litera...       1977-01-01
# 8744  Fiction,Mystery,Historical Fiction,Thriller,Fa...       1988-12-27
# 8745  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...       1984-01-01
#
#                    Author                                              Title  \
# 0              Harper Lee                              To Kill a Mockingbird
# 1           George Orwell
# 2     F. Scott Fitzgerald                                   The Great Gatsby
# 3            J.K. Rowling               Harry Potter and the Sorcerers Stone
# 4           George Orwell                                        Animal Farm
# ...                   ...                                                ...
# 8741    François Schuiten                           Les murailles de Samaris
# 8742        Mickee Madden                                         Everlastin
# 8743       Aleksander Wat  Secolul meu confesiunile unui intelectual euro...
# 8744    Katherine Neville                                          The Eight
# 8745    François Schuiten                                  Fever in Urbicand
#
#      Rating  Ratings Count  Reviews Count             Author Info  Auth_Books  \
# 0      4.26        6296391         120579     82 /13.7k followers        82.0
# 1      4.19        4761335         122911  1,404 /45.3k followers      1404.0
# 2      3.93        5365833         109920  1,933 /24.2k followers      1933.0
# 3      4.47       10332287         167714     754 /227k followers       754.0
# 4      3.99        4006287         102011  1,404 /45.3k followers      1404.0
# ...     ...            ...            ...                     ...         ...
# 8741   3.93            949             82      120 /134 followers       120.0
# 8742   3.59            214             30        27 /20 followers        27.0
# 8743   4.20            186             23         31 /9 followers        31.0
# 8744   3.93          43688           3214     24 /1,354 followers        24.0
# 8745   4.15            747             58      120 /134 followers       120.0
#
#       Auth_Followers  k1    k2
# 0            13700.0   1  1000
# 1            45300.0   1  1000
# 2            24200.0   1  1000
# 3           227000.0   1  1000
# 4            45300.0   1  1000
# ...              ...  ..   ...
# 8741           134.0   1     1
# 8742            20.0   1     1
# 8743             9.0   1     1
# 8744          1354.0   1     1
# 8745           134.0   1     1
#
# [7518 rows x 12 columns]

# %%
import pandas as pd



# Columns to remove
columns_to_drop = ['Author Info', 'k1', 'k2']

# Remove the specified columns
combined_df = combined_df.drop(columns=columns_to_drop)

combined_df
# Out:
#                                                   Genre Publication Date  \
# 0     Fiction,Historical Fiction,School Literature,Y...       1960-07-11
# 1     Classics,Fiction,Science,Fiction,Dystopia,Lite...       1949-06-08
# 2     Fiction,School Historical Fiction,Romance,Lite...       1925-04-10
# 3     Fantasy,Fiction,Young,Adult,Magic,Childrens,Mi...       1997-06-26
# 4     Classics,Fiction,Dystopia,Fantasy,School Liter...       1945-08-17
# ...                                                 ...              ...
# 8741  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,S...       1983-01-01
# 8742  Romance,Paranormal,Historical Ghosts,Paranorma...       1994-01-01
# 8743  History,Nonfiction,Poland,Memoir,Polish,Litera...       1977-01-01
# 8744  Fiction,Mystery,Historical Fiction,Thriller,Fa...       1988-12-27
# 8745  Comics,Graphic,Novels,Bande,Dessinée,Fantasy,F...       1984-01-01
#
#                    Author                                              Title  \
# 0              Harper Lee                              To Kill a Mockingbird
# 1           George Orwell
# 2     F. Scott Fitzgerald                                   The Great Gatsby
# 3            J.K. Rowling               Harry Potter and the Sorcerers Stone
# 4           George Orwell                                        Animal Farm
# ...                   ...                                                ...
# 8741    François Schuiten                           Les murailles de Samaris
# 8742        Mickee Madden                                         Everlastin
# 8743       Aleksander Wat  Secolul meu confesiunile unui intelectual euro...
# 8744    Katherine Neville                                          The Eight
# 8745    François Schuiten                                  Fever in Urbicand
#
#      Rating  Ratings Count  Reviews Count  Auth_Books  Auth_Followers
# 0      4.26        6296391         120579        82.0         13700.0
# 1      4.19        4761335         122911      1404.0         45300.0
# 2      3.93        5365833         109920      1933.0         24200.0
# 3      4.47       10332287         167714       754.0        227000.0
# 4      3.99        4006287         102011      1404.0         45300.0
# ...     ...            ...            ...         ...             ...
# 8741   3.93            949             82       120.0           134.0
# 8742   3.59            214             30        27.0            20.0
# 8743   4.20            186             23        31.0             9.0
# 8744   3.93          43688           3214        24.0          1354.0
# 8745   4.15            747             58       120.0           134.0
#
# [7518 rows x 9 columns]

# %%
combined_df['Rating'] = combined_df['Rating'].astype(float)
combined_df['Reviews Count'] = combined_df['Reviews Count'].astype(float)
combined_df['Ratings Count'] = combined_df['Ratings Count'].astype(float)
combined_df['Publication Date'] = pd.to_datetime(combined_df['Publication Date'])
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7518 entries, 0 to 8745
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Genre             7518 non-null   object
#  1   Publication Date  7518 non-null   datetime64[ns]
#  2   Author            7518 non-null   object
#  3   Title             7518 non-null   object
#  4   Rating            7518 non-null   float64
#  5   Ratings Count     7518 non-null   float64
#  6   Reviews Count     7518 non-null   float64
#  7   Auth_Books        7518 non-null   float64
#  8   Auth_Followers    7518 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 587.3+ KB

# %%
combined_df['Publication Date'] = pd.to_datetime(combined_df['Publication Date'])

# %%
combined_df.describe()
# Out:
#                     Publication Date       Rating  Ratings Count  \
# count                           7518  7518.000000   7.518000e+03
# mean   1971-12-23 01:52:14.557063048     4.020919   5.236332e+04
# min              1697-01-01 00:00:00     2.550000   2.000000e+00
# 25%              1957-01-01 00:00:00     3.860000   1.494250e+03
# 50%              1979-06-10 00:00:00     4.030000   6.622000e+03
# 75%              1993-01-01 00:00:00     4.200000   2.621750e+04
# max              2018-11-01 00:00:00     4.830000   1.033229e+07
# std                              NaN     0.257673   2.616621e+05
#
#        Reviews Count     Auth_Books  Auth_Followers
# count    7518.000000    7518.000000     7518.000000
# mean     2012.454908    1195.456903    11915.076350
# min         0.000000       1.000000        1.000000
# 25%       102.000000      58.000000      246.000000
# 50%       397.500000     149.000000     1249.500000
# 75%      1398.000000     415.000000     5499.000000
# max    167714.000000  791000.000000   854000.000000
# std      6676.816584   23009.197908    64791.866505

# %%
combined_df.describe(include='object')
# Out:
#          Genre        Author Title
# count     7518          7518  7518
# unique    6903          3519  7293
# top     Poetry  V.C. Andrews
# freq        33            44    28

# %%
import matplotlib.pyplot as plt

# Select the 4 columns you want to plot
columns_to_plot = [ 'Reviews Count', 'Ratings Count', 'Auth_Books','Auth_Followers']

# Create the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Plot the histograms
for i, column in enumerate(columns_to_plot):
    row = i // 2
    col = i % 2
    axes[row, col].hist(combined_df[column], bins=100)
    axes[row, col].set_title(column)
    axes[row, col].set_xlabel('Value')
    axes[row, col].set_ylabel('Frequency')

    # Set the number of x-ticks within the desired range
    min_val = combined_df[column].min()
    max_val = combined_df[column].max() + 1000
    axes[row, col].set_xticks(np.linspace(min_val, max_val,5))  # 5 ticks in the range

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Select the 5 columns you want to plot, including 'Auth_Followers'
columns_to_plot = ['Rating', 'Reviews Count', 'Ratings Count', 'Auth_Books', 'Auth_Followers']

# ... (rest of your code for handling outliers)

# Adjust subplot layout for 5 plots (3 rows, 2 columns)
fig, axes = plt.subplots(3, 2, figsize=(10, 15))

# Plot the displot
for i, column in enumerate(columns_to_plot):
    row = i // 2
    col = i % 2
    sns.histplot(combined_df[column], kde=True, ax=axes[row, col])  # Use histplot for displot
    axes[row, col].set_title(column)
    axes[row, col].set_xlabel('Value')
    axes[row, col].set_ylabel('Frequency')

# Remove the unused subplot (if any)
if len(columns_to_plot) % 2 != 0:
    fig.delaxes(axes[-1, -1])

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the 4 columns you want to plot
columns_to_plot = ['Auth_Followers', 'Reviews Count', 'Ratings Count', 'Auth_Books']

# Create the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Plot the box plots
for i, column in enumerate(columns_to_plot):
    row = i // 2
    col = i % 2
    sns.boxplot(y=combined_df[column], ax=axes[row, col])  # Use boxplot
    axes[row, col].set_title(column)
    axes[row, col].set_ylabel('Value')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Assuming 'Publication Date' is a string Series
# Convert to datetime with dayfirst
combined_df['Publication Date'] = pd.to_datetime(combined_df['Publication Date'], dayfirst=True)

# Check the data type
print(combined_df['Publication Date'].dtype)
combined_df['Publication Date'].unique()
# Out:
# datetime64[ns]
# <DatetimeArray>
# ['1960-07-11 00:00:00', '1949-06-08 00:00:00', '1925-04-10 00:00:00',
#  '1997-06-26 00:00:00', '1945-08-17 00:00:00', '1937-09-21 00:00:00',
#  '1943-04-06 00:00:00', '1953-10-19 00:00:00', '1951-07-16 00:00:00',
#  '1950-10-16 00:00:00',
#  ...
#  '1697-01-01 00:00:00', '1982-02-01 00:00:00', '1939-09-09 00:00:00',
#  '1988-05-12 00:00:00', '1985-09-25 00:00:00', '1997-09-29 00:00:00',
#  '1967-08-01 00:00:00', '1994-10-27 00:00:00', '2000-10-02 00:00:00',
#  '1988-12-27 00:00:00']
# Length: 1799, dtype: datetime64[ns]

# %%
import pandas as pd

# Select the columns you want to check for outliers
columns_to_check = ['Rating', 'Reviews Count', 'Ratings Count', 'Auth_Books', 'Auth_Followers','Publication Date']

for column in columns_to_check:
    # Calculate IQR
    Q1 = combined_df[column].quantile(0.25)
    Q3 = combined_df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define outlier boundaries
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
# Identify outlier records
    outliers_s = combined_df[((combined_df[column] < lower_bound))]
    outliers_b =combined_df[(combined_df[column] > upper_bound)]

    # Print outlier records for the current column
    print(f"Outliers in column '{column}':")
    print(outliers_b.min())
    print("-" * 30)  # Separator between columns
# Out:
# Outliers in column 'Rating':
# Genre               Christian,Fiction,Christian,Historical Fiction...
# Publication Date                                  1918-01-01 00:00:00
# Author                                            Anița Nandriș-Cudla
# Title                            de ani în Siberia amintiri din viaţă
# Rating                                                           4.72
# Ratings Count                                                     5.0
# Reviews Count                                                     1.0
# Auth_Books                                                        1.0
# Auth_Followers                                                    1.0
# dtype: object
# ------------------------------
# Outliers in column 'Reviews Count':
# Genre               Biography,Nonfiction,History,Africa,Memoir,Aut...
# Publication Date                                  1886-01-01 00:00:00
# Author                                                     A.A. Milne
# Title
# Rating                                                           3.34
# Ratings Count                                                 23565.0
# Reviews Count                                                  3349.0
# Auth_Books                                                        2.0
# Auth_Followers                                                   52.0
# dtype: object
# ------------------------------
# Outliers in column 'Ratings Count':
# Genre               Art,Nonfiction,Classics,Biography,History,Art,...
# Publication Date                                  1812-01-01 00:00:00
# Author                                                     A.A. Milne
# Title
# Rating                                                           3.34
# Ratings Count                                                 63384.0
# Reviews Count                                                   260.0
# Auth_Books                                                        2.0
# Auth_Followers                                                    8.0
# dtype: object
# ------------------------------
# Outliers in column 'Auth_Books':
# Genre                           Animals
# Publication Date    1697-01-01 00:00:00
# Author                       A.A. Milne
# Title
# Rating                             2.55
# Ratings Count                       6.0
# Reviews Count                       0.0
# Auth_Books                        954.0
# Auth_Followers                     17.0
# dtype: object
# ------------------------------
# Outliers in column 'Auth_Followers':
# Genre               Biography,Literature,Short,Stories,Nonfiction,...
# Publication Date                                  1886-01-01 00:00:00
# Author                                                Agatha Christie
# Title
# Rating                                                           2.82
# Ratings Count                                                    23.0
# Reviews Count                                                     2.0
# Auth_Books                                                       35.0
# Auth_Followers                                                13400.0
# dtype: object
# ------------------------------
# Outliers in column 'Publication Date':
# Genre               NaN
# Publication Date    NaT
# Author              NaN
# Title               NaN
# Rating              NaN
# Ratings Count       NaN
# Reviews Count       NaN
# Auth_Books          NaN
# Auth_Followers      NaN
# dtype: object
# ------------------------------

# %%
import pandas as pd
import numpy as np

# Select the columns you want to check for outliers
columns_to_check = ['Rating', 'Reviews Count', 'Ratings Count', 'Auth_Books', 'Auth_Followers','Publication Date']



for column in columns_to_check:
    # Calculate IQR
    Q1 = combined_df[column].quantile(0.25)
    Q3 = combined_df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define outlier boundaries
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter the DataFrame to remove outliers
    combined_df = combined_df[(combined_df[column] >= lower_bound) & (combined_df[column] <= upper_bound)]

# Now, df_filtered contains the data without outliers
print(combined_df.shape)  # Check the shape to see how many rows were removed
# Out:
# (4460, 9)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the 4 columns you want to plot
columns_to_plot = ['Auth_Followers', 'Reviews Count', 'Ratings Count', 'Auth_Books']

# Create the figure and axes
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Plot the box plots
for i, column in enumerate(columns_to_plot):
    row = i // 2
    col = i % 2
    sns.boxplot(y=combined_df[column], ax=axes[row, col])  # Use boxplot
    axes[row, col].set_title(column)
    axes[row, col].set_ylabel('Value')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Select the 5 columns you want to plot, including 'Auth_Followers'
columns_to_plot = ['Rating', 'Reviews Count', 'Ratings Count', 'Auth_Books', 'Auth_Followers']

# ... (rest of your code for handling outliers)

# Adjust subplot layout for 5 plots (3 rows, 2 columns)
fig, axes = plt.subplots(3, 2, figsize=(10, 15))

# Plot the displot
for i, column in enumerate(columns_to_plot):
    row = i // 2
    col = i % 2
    sns.histplot(combined_df[column], kde=True, ax=axes[row, col])  # Use histplot for displot
    axes[row, col].set_title(column)
    axes[row, col].set_xlabel('Value')
    axes[row, col].set_ylabel('Frequency')

# Remove the unused subplot (if any)
if len(columns_to_plot) % 2 != 0:
    fig.delaxes(axes[-1, -1])

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
combined_df.to_csv('book data2.csv', index=False)

# %%
combined_df['Title'].unique()
# Out:
# array(['Sometimes a Great Notion', 'The Gulag Archipelago ',
#        'The Alexandria Quartet', ..., 'Everlastin',
#        'Secolul meu confesiunile unui intelectual european',
#        'Fever in Urbicand'], dtype=object)

# %%
combined_df.isnull().sum()
# Out:
# Genre               0
# Publication Date    0
# Author              0
# Title               0
# Rating              0
# Ratings Count       0
# Reviews Count       0
# Auth_Books          0
# Auth_Followers      0
# dtype: int64

# %%
combined_df['Genre'].value_counts()
# Out:
# Genre
# Poetry                                                                                         30
# Fiction                                                                                        10
# Science,Fiction,Young,Adult,Fiction,Fantasy,Childrens,Middle,Grade,Aliens,more                  9
# Fantasy,Fiction,Young,Adult,Childrens,Animals,Adventure,Middle,Grade,more                       8
# Science,Fiction,Young,Adult,Fiction,Childrens,Fantasy,Middle,Grade,Aliens,more                  6
#                                                                                                ..
# Historical Fiction,Fiction,Asia,Classics,Asian,Literature,Novels,Travel,more                    1
# Fiction,Dutch,Literature,Classics,Short,Stories,Literature,Audiobookth,Century                  1
# Fiction,Historical Fiction,Literature,Literary,Fiction,Historical Nature,Novels,more            1
# Fiction,Historical Fiction,Canada,Historical Race,Canadian,Literature,African,American,more     1
# Comics,Graphic,Novels,Bande,Dessinée,Fantasy,France,Science,Fiction,Architecture,more           1
# Name: count, Length: 4221, dtype: int64
